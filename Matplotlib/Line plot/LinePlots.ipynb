# %% [markdown]
# # I created a random dataset which named data.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data.csv')

# %%
sub_data = data[['CalendarYear','CalendarQuarter','SalesAmount','Cost' , 'Quantity']]

# %%
profit = (data['SalesAmount'].sub(data['Cost'])).mul(data['Quantity'])

# %%
result = pd.concat((sub_data , profit.rename('Profit')) , axis=1)

# %%
b = result.groupby(['CalendarYear' , 'CalendarQuarter'] ,  axis=0)

# %%
a = result.groupby(['CalendarYear']).sum()['Profit']
plt.plot(a.keys() , a , label='Profit' , color='#FFA500' , marker='v')
plt.grid(True)
plt.tight_layout
plt.title('Summation of profit according to the years')
plt.ylabel("Profit")
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
slices = result.groupby(['CalendarYear']).sum()['Profit'].sum()
slices
# Out:
# 894322.0

# %%
x = result.groupby(['CalendarYear']).sum()['Profit'][0:1][0:1]

# %%
x / slices
# Out:
# CalendarYear
# 2000    0.037475
# Name: Profit, dtype: float64

# %%
data.columns
# Out:
# Index(['ProductName', 'ProductCategoryName', 'CalendarYear', 'CalendarQuarter',
#        'MonthName', 'DayName', 'Quantity', 'SalesAmount', 'Cost',
#        'StoreGeographyID', 'City', 'CityCode'],
#       dtype='object')

# %%
sub_data_2 = data[['ProductCategoryName','SalesAmount','Cost' , 'Quantity']]
result_2 = pd.concat((sub_data_2 , profit.rename('Profit')) , axis=1)

# %%
x = result_2.groupby(['ProductCategoryName']).sum()['Profit']
plt.plot(x.keys() , x , label='Profit' , color='#9400D3' , marker='o' , linestyle='--')
plt.title('Summation of profit according to the products')
plt.tight_layout
plt.grid(True)
plt.ylabel("Profit")
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.legend()
plt.show()
